# %%
import pandas as pd
import requests
import json
import csv
import time
import datetime
from datetime import datetime

# %%
column_names = ['Date']
for i in range(1,26):
    column_names.append('Top'+str(i))

df = pd.DataFrame(columns=column_names)
for i in range(1, 13):
    month = "2020Data/2020month"+ str(i) + ".csv"
    monthNews = pd.read_csv(month)
    monthNews = monthNews.drop(monthNews.columns[0], axis=1)
    monthNews['Day'] = monthNews["Publish Date"].apply(lambda date: int(date.split(" ")[0].split("-")[2]))
    days = set(monthNews['Day'].tolist())
    for day in days:
        day_top_news = monthNews.loc[monthNews["Day"] == day].sort_values(by=['Score'], ascending=False)[:25]
        day_top_news_list = day_top_news.values.tolist()
        new_row = [day_top_news['Publish Date'].values[0].split(" ")[0]]
        for row in day_top_news_list:
            new_row.append(row[1])
       
        df.loc[len(df.index)] = new_row 
        new_row = []
        day_top_news_list = []

print(df.shape)
df.to_csv("top25news2020.csv", index = False)
# Out:
# (366, 26)

# %%
df2 = pd.read_csv("yeah.csv")
df2.head(10)
# Out:
#          Date                                               Top1  ...                                              Top24                                              Top25
# 0  2020-01-01  More than 1 million in Hong Kong New Year's Da...  ...  Carlos Ghosn: Ex-Nissan boss escaped Japan in ...  Coalition was hesitant to take action on clima...
# 1  2020-01-02  Outrage and Disgust After 'Serial Killer' Navy...  ...  Taiwan passes bill against China influence ahe...  President Tsai Ing-wen Calls on Beijing to Tre...
# 2  2020-01-03  Trump accused of hypocrisy for ordering the po...  ...  Pompeo says Trump made the world safer by kill...  The Australian: Murdoch-owned newspaper accuse...
# 3  2020-01-04  Protesters break into PM Scott Morrison’s home...  ...  Pop singer Pink donates $500,000 to Australian...  Get ready for tens of millions of climate refu...
# 4  2020-01-05  The United States' main allies are abandoning ...  ...  Russian foreign minister stresses that Soleima...  Russian and Chinese foreign ministers in a pho...
# 5  2020-01-06  The Trump administration is barring Iran’s top...  ...  Thousands march in France over decision to not...  Germany: Trump's Iraq sanctions threat 'not he...
# 6  2020-01-07  Trump officials are bending over backwards to ...  ...  Philippine President Rodrigo Duterte’s campaig...  Pentagon Contradicts Trump, Says U.S. Won't St...
# 7  2020-01-08             Multiple rockets hit Taji base in Iraq  ...     Canada 'temporarily' moving troops out of Iraq  Tweet calling for killing of Muslims in India ...
# 8  2020-01-09  Pentagon officials and Iraqi intelligence conf...  ...  Japanese billionaire giving out $9 million in ...  Raise taxes on the rich to tackle inequality, ...
# 9  2020-01-10  Trump Complains About Not Winning the Nobel Pe...  ...  Thousands protest in Australia to "Sack Scomo"...  A Blind Refugee With Schizophrenia Was In Dete...
#
# [10 rows x 26 columns]
