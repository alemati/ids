# %%
import pandas as pd
import requests
import json
import csv
import time
import datetime
from datetime import datetime

# %%
column_names = ['Date']
for i in range(1,26):
    column_names.append('Top'+str(i))

df = pd.DataFrame(columns=column_names)
for i in range(1, 13):
    month = "2019Data/2019month"+ str(i) + ".csv" #change folder if needed
    monthNews = pd.read_csv(month)
#    monthNews = monthNews.drop(monthNews.columns[0], axis=1)
    monthNews['Day'] = monthNews["Publish Date"].apply(lambda date: int(date.split(" ")[0].split("-")[2]))
    days = set(monthNews['Day'].tolist())
    for day in days:
        day_top_news = monthNews.loc[monthNews["Day"] == day].sort_values(by=['Score'], ascending=False)[:25]
        day_top_news_list = day_top_news.values.tolist()
        new_row = [day_top_news['Publish Date'].values[0].split(" ")[0]]
        for row in day_top_news_list:
            new_row.append(row[1])
        
        while len(new_row) < 26:
          new_row.append(" ")
        
        df.loc[len(df.index)] = new_row 
        new_row = []
        day_top_news_list = []

print(df.shape)
df.to_csv("top25news2019.csv", index = False)
# Out:
# (370, 26)

# %%
df2 = pd.read_csv("top25news2019.csv")
df2.head(10)
# Out:
#          Date                                               Top1  ...                                              Top24                                              Top25
# 0  2019-01-01  Women say Morocco's invasive 'virginity tests'...  ...  Venice to charge day-trippers up to €10 to ent...  Serbia Starts 2019 Off Right By Outlawing Fur ...
# 1  2019-01-02  Former Blackwater guard convicted for 2007 mas...  ...  Netflix Drops Hasan Minhaj Episode In Saudi Ar...  Nasa's New Horizons: 'Snowman' shape of distan...
# 2  2019-01-03  Hasan Minhaj responds after Netflix pulls epis...  ...  Mexican experts have found the first temple of...  Russia Announces Plans To Set Up Its First Eve...
# 3  2019-01-04  Workers at Amazon’s biggest warehouse in Spain...  ...  Heatwave conditions predicted to affect Austra...  Brazilian President Jair Bolsonaro—whose inaug...
# 4  2019-01-05  All children to learn CPR and basic first aid ...  ...  Japanese lawmaker takes fire for saying a nati...  Smokers and problem drinkers who are admitted ...
# 5  2019-01-06  Former Canadian Prime Minister tweets that Tru...  ...  Saudi woman 'trapped at Bangkok airport trying...     Afghan gold mine collapses and kills 30 people
# 6  2019-01-07  Former Venezuela Supreme Court judge flees to ...  ...  Global warming of oceans is equivalent to an a...  Britons would now vote to stay in EU, want sec...
# 7  2019-01-08  Canada helped pressure Thailand to protect Sau...  ...  Chinese scientist who genetically edited babie...  The monarch butterfly population in California...
# 8  2019-01-09  A Turkish journalist has been sentenced to mor...  ...    Climate Change: 'Right to repair' gathers force  FBI 'turned El Chapo's IT expert' to bring dow...
# 9  2019-01-10  Trump says he never said that Mexico would dir...  ...  Nepal woman and children die in banned 'menstr...  Hubble Space Telescope's main camera stops wor...
#
# [10 rows x 26 columns]
